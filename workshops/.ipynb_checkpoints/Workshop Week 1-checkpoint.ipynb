# %% [markdown]
# # 1. Simple Statistics and NLTK
#
# The following exercises use a portion of the Gutenberg corpus that is stored in the corpus dataset of NLTK. [The Project Gutenberg](http://www.gutenberg.org/) is a large collection of electronic books that are out of copyright. These books are free to download for reading, or for our case, for doing a little of corpus analysis.
#
# To obtain the list of files of NLTK's Gutenberg corpus, type the following commands:

# %%
import nltk
nltk.download('gutenberg')
nltk.corpus.gutenberg.fileids()
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\timo\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# To obtain all words in the entire Gutenberg corpus of NLTK, type the following:

# %%
gutenbergwords = nltk.corpus.gutenberg.words()

# %% [markdown]
# Now you can find the total number of words, and the first 10 words (do not attempt to display all the words or your computer will freeze!):

# %%
len(gutenbergwords)
# Out:
# 2621613

# %%
gutenbergwords[:10]
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', 'VOLUME', 'I', 'CHAPTER']

# %% [markdown]
# You can also find the words of just a selection of documents, as shown below. For more details of what information you can extract from this corpus, read the "Gutenberg corpus" section of the [NLTK book chapter 2](http://www.nltk.org/book_1ed/ch02.html), section 2.1.

# %% [markdown]
# ### Exercise 1.1
# *Write Python code that prints the 10 most common words in each of the documents of the Gutenberg corpus. Can you identify any similarities among them?*

# %%
import collections
for text in nltk.corpus.gutenberg.fileids():
    actualtext = nltk.corpus.gutenberg.words(text)
    print(text)
    print(collections.Counter(actualtext).most_common(10));
# Out:
# austen-emma.txt
# [(',', 11454), ('.', 6928), ('to', 5183), ('the', 4844), ('and', 4672), ('of', 4279), ('I', 3178), ('a', 3004), ('was', 2385), ('her', 2381)]
# austen-persuasion.txt
# [(',', 6750), ('the', 3120), ('to', 2775), ('.', 2741), ('and', 2739), ('of', 2564), ('a', 1529), ('in', 1346), ('was', 1330), (';', 1290)]
# austen-sense.txt
# [(',', 9397), ('to', 4063), ('.', 3975), ('the', 3861), ('of', 3565), ('and', 3350), ('her', 2436), ('a', 2043), ('I', 2004), ('in', 1904)]
# bible-kjv.txt
# [(',', 70509), ('the', 62103), (':', 43766), ('and', 38847), ('of', 34480), ('.', 26160), ('to', 13396), ('And', 12846), ('that', 12576), ('in', 12331)]
# blake-poems.txt
# [(',', 680), ('the', 351), ('.', 201), ('And', 176), ('and', 169), ('of', 131), ('I', 130), ('in', 116), ('a', 108), ("'", 104)]
# bryant-stories.txt
# [(',', 3481), ('the', 3086), ('and', 1873), ('.', 1817), ('to', 1165), ('a', 988), ('"', 900), ('he', 872), ('of', 801), ('was', 706)]
# burgess-busterbrown.txt
# [('.', 823), (',', 822), ('the', 639), ('he', 562), ('and', 484), ('to', 426), ("'", 401), ('of', 326), ('that', 285), ('a', 275)]
# carroll-alice.txt
# [(',', 1993), ("'", 1731), ('the', 1527), ('and', 802), ('.', 764), ('to', 725), ('a', 615), ('I', 543), ('it', 527), ('she', 509)]
# chesterton-ball.txt
# [(',', 4547), ('the', 4523), ('.', 3589), ('of', 2529), ('and', 2488), ('a', 2184), ('"', 1751), ('to', 1558), ('in', 1355), ('that', 1120)]
# chesterton-brown.txt
# [('the', 4321), (',', 4069), ('.', 2784), ('of', 2087), ('and', 2074), ('a', 2074), ('"', 1461), ('to', 1378), ('in', 1205), ('was', 1141)]
# chesterton-thursday.txt
# [(',', 3488), ('the', 3291), ('.', 2717), ('a', 1713), ('of', 1710), ('and', 1568), ('"', 1336), ('to', 1045), ('in', 888), ('I', 885)]
# edgeworth-parents.txt
# [(',', 15219), ('the', 7149), ('.', 6945), ('to', 5150), ('and', 4769), ('"', 3880), ('of', 3730), ('I', 3656), ("'", 3293), ('a', 3017)]
# melville-moby_dick.txt
# [(',', 18713), ('the', 13721), ('.', 6862), ('of', 6536), ('and', 6024), ('a', 4569), ('to', 4542), (';', 4072), ('in', 3916), ('that', 2982)]
# milton-paradise.txt
# [(',', 10198), ('and', 2799), ('the', 2505), (';', 2317), ('to', 1758), ('of', 1486), ('.', 1254), ('in', 1083), ('his', 986), ('with', 876)]
# shakespeare-caesar.txt
# [(',', 2204), ('.', 1296), ('I', 531), ('the', 502), (':', 499), ('and', 409), ("'", 384), ('to', 370), ('you', 342), ('of', 336)]
# shakespeare-hamlet.txt
# [(',', 2892), ('.', 1886), ('the', 860), ("'", 729), ('and', 606), ('of', 576), ('to', 576), (':', 565), ('I', 553), ('you', 479)]
# shakespeare-macbeth.txt
# [(',', 1962), ('.', 1235), ("'", 637), ('the', 531), (':', 477), ('and', 376), ('I', 333), ('of', 315), ('to', 311), ('?', 241)]
# whitman-leaves.txt
# [(',', 17713), ('the', 8814), ('and', 4797), ('of', 4127), ('I', 2932), ("'", 2362), ('to', 1930), ('-', 1774), ('.', 1769), ('in', 1714)]

# %% [markdown]
# We can see that the list of most common words is very similar in all documents, and they are all words that do not have much meaning, or they are not words at all but punctuation marks.

# %% [markdown]
# ### Exercise 1.2
# *Find the words with length of more than 7 characters in the complete Gutenberg corpus.*

# %%
[w for w in gutenbergwords if len(w) > 7]
# Out:
# ['Woodhouse',
#  'handsome',
#  'comfortable',
#  'disposition',
#  'blessings',
#  'existence',
#  'distress',
#  'youngest',
#  'daughters',
#  'affectionate',
#  'indulgent',
#  'consequence',
#  'marriage',
#  'mistress',
#  'indistinct',
#  'remembrance',
#  'caresses',
#  'supplied',
#  'excellent',
#  'governess',
#  'affection',
#  'Woodhouse',
#  'governess',
#  'daughters',
#  'particularly',
#  'intimacy',
#  'governess',
#  'mildness',
#  'restraint',
#  'authority',
#  'together',
#  'mutually',
#  'attached',
#  'esteeming',
#  'judgment',
#  'directed',
#  'situation',
#  'disposition',
#  'disadvantages',
#  'threatened',
#  'enjoyments',
#  'unperceived',
#  'misfortunes',
#  'disagreeable',
#  'consciousness',
#  'mournful',
#  'continuance',
#  'together',
#  'prospect',
#  'composed',
#  'happiness',
#  'unexceptionable',
#  'character',
#  'suitable',
#  'pleasant',
#  'satisfaction',
#  'considering',
#  'generous',
#  'friendship',
#  'promoted',
#  'recalled',
#  'kindness',
#  'kindness',
#  'affection',
#  'illnesses',
#  'childhood',
#  'gratitude',
#  'intercourse',
#  'unreserve',
#  'followed',
#  'Isabella',
#  'marriage',
#  'tenderer',
#  'recollection',
#  'companion',
#  'possessed',
#  'intelligent',
#  'informed',
#  'interested',
#  'concerns',
#  'peculiarly',
#  'interested',
#  'pleasure',
#  'affection',
#  'difference',
#  'advantages',
#  'domestic',
#  'suffering',
#  'intellectual',
#  'solitude',
#  'companion',
#  'conversation',
#  'rational',
#  'disparity',
#  'Woodhouse',
#  'increased',
#  'constitution',
#  'valetudinarian',
#  'activity',
#  'everywhere',
#  'friendliness',
#  'recommended',
#  'comparatively',
#  'matrimony',
#  'November',
#  'struggled',
#  'Hartfield',
#  'Christmas',
#  'Isabella',
#  'children',
#  'pleasant',
#  'Highbury',
#  'populous',
#  'amounting',
#  'Hartfield',
#  'separate',
#  'shrubberies',
#  'afforded',
#  'Woodhouses',
#  'consequence',
#  'acquaintance',
#  'universally',
#  'accepted',
#  'melancholy',
#  'impossible',
#  'necessary',
#  'cheerful',
#  'required',
#  'depressed',
#  'Matrimony',
#  'disagreeable',
#  'reconciled',
#  'daughter',
#  'marrying',
#  'compassion',
#  'entirely',
#  'affection',
#  'selfishness',
#  'differently',
#  'disposed',
#  'Hartfield',
#  'cheerfully',
#  'thoughts',
#  'impossible',
#  'humoured',
#  'pleasant',
#  'excellent',
#  'thoroughly',
#  'deserves',
#  'advantage',
#  'Randalls',
#  'distance',
#  'carriage',
#  'carriage',
#  'Randalls',
#  'daughter',
#  'housemaid',
#  'anywhere',
#  'mentioned',
#  'slighted',
#  'Whenever',
#  'curtseys',
#  'needlework',
#  'excellent',
#  'somebody',
#  'Whenever',
#  'daughter',
#  'exertions',
#  'maintain',
#  'backgammon',
#  'tolerably',
#  'attacked',
#  'backgammon',
#  'immediately',
#  'afterwards',
#  'unnecessary',
#  'Knightley',
#  'sensible',
#  'intimate',
#  'particularly',
#  'connected',
#  'Isabella',
#  'Highbury',
#  'frequent',
#  'directly',
#  'connexions',
#  'returned',
#  'Hartfield',
#  'Brunswick',
#  'circumstance',
#  'animated',
#  'Woodhouse',
#  'Knightley',
#  'cheerful',
#  'inquiries',
#  'Isabella',
#  'children',
#  'answered',
#  'satisfactorily',
#  'Woodhouse',
#  'gratefully',
#  'observed',
#  'Knightley',
#  'shocking',
#  'beautiful',
#  'moonlight',
#  'surprising',
#  'dreadfully',
#  'breakfast',
#  'congratulations',
#  'tolerably',
#  'business',
#  'Woodhouse',
#  'possibly',
#  'question',
#  'dependence',
#  'independence',
#  'Especially',
#  'fanciful',
#  'troublesome',
#  'creature',
#  'playfully',
#  'certainly',
#  'Woodhouse',
#  'sometimes',
#  'fanciful',
#  'troublesome',
#  'Knightley',
#  'horrible',
#  'Knightley',
#  'Knightley',
#  'Woodhouse',
#  'particularly',
#  'agreeable',
#  'circumstance',
#  'Knightley',
#  'reflection',
#  'charmingly',
#  'punctual',
#  'Knightley',
#  'impossible',
#  'companion',
#  'Knightley',
#  'marriage',
#  'advantage',
#  'acceptable',
#  'important',
#  'comfortable',
#  'provision',
#  'therefore',
#  'pleasure',
#  'forgotten',
#  'considerable',
#  'Knightley',
#  'foretell',
#  'whatever',
#  'greatest',
#  'amusement',
#  'perfectly',
#  'comfortable',
#  'constantly',
#  'occupied',
#  'business',
#  'acceptable',
#  'wherever',
#  'cheerful',
#  'certainly',
#  'deathbed',
#  'nonsense',
#  'believed',
#  'Broadway',
#  'gallantry',
#  'borrowed',
#  'umbrellas',
#  'Mitchell',
#  'instance',
#  'understand',
#  'Knightley',
#  'supposes',
#  'endeavour',
#  'properly',
#  'delicately',
#  'endeavouring',
#  'marriage',
#  'employment',
#  'planning',
#  'yourself',
#  'yourself',
#  'afterwards',
#  'pleasure',
#  'cleverer',
#  'entirely',
#  'pictures',
#  'something',
#  'promoted',
#  'encouragements',
#  'smoothed',
#  'Hartfield',
#  'comprehend',
#  'straightforward',
#  'rational',
#  'unaffected',
#  'concerns',
#  'yourself',
#  'interference',
#  'rejoined',
#  'Woodhouse',
#  'understanding',
#  'grievously',
#  'Highbury',
#  'deserves',
#  'comfortably',
#  'attention',
#  'Knightley',
#  'pleasure',
#  'Knightley',
#  'laughing',
#  'entirely',
#  'Highbury',
#  'respectable',
#  'generations',
#  'gentility',
#  'property',
#  'received',
#  'education',
#  'succeeding',
#  'independence',
#  'indisposed',
#  'pursuits',
#  'brothers',
#  'satisfied',
#  'cheerful',
#  'entering',
#  'embodied',
#  'favourite',
#  'military',
#  'introduced',
#  'Churchill',
#  'Yorkshire',
#  'Churchill',
#  'surprized',
#  'importance',
#  'connexion',
#  'Churchill',
#  'proportion',
#  'dissuaded',
#  'marriage',
#  'infinite',
#  'mortification',
#  'Churchill',
#  'unsuitable',
#  'connexion',
#  'happiness',
#  'goodness',
#  'resolution',
#  'unreasonable',
#  'unreasonable',
#  'luxuries',
#  'comparison',
#  'Enscombe',
#  'Churchill',
#  'Enscombe',
#  'considered',
#  'especially',
#  'Churchills',
#  'marriage',
#  'maintain',
#  'relieved',
#  'additional',
#  'softening',
#  'lingering',
#  'reconciliation',
#  'Churchill',
#  'children',
#  'creature',
#  'scruples',
#  'reluctance',
#  'supposed',
#  'overcome',
#  'considerations',
#  'Churchills',
#  'situation',
#  'complete',
#  'desirable',
#  'brothers',
#  'established',
#  'afforded',
#  'favourable',
#  'employment',
#  'Highbury',
#  'occupation',
#  'pleasures',
#  'eighteen',
#  'cheerfully',
#  'realised',
#  'competence',
#  'purchase',
#  'adjoining',
#  'Highbury',
#  'portionless',
#  'according',
#  'friendly',
#  'disposition',
#  'influence',
#  'tyrannic',
#  'influence',
#  'determination',
#  'settling',
#  'purchase',
#  'Randalls',
#  'Randalls',
#  'steadily',
#  'accomplished',
#  'obtained',
#  'beginning',
#  'existence',
#  'probability',
#  'happiness',
#  'marriage',
#  'delightful',
#  'pleasantest',
#  'gratitude',
#  'adoption',
#  'Churchill',
#  'unlikely',
#  'therefore',
#  'assistance',
#  'apprehension',
#  'capricious',
#  'governed',
#  'entirely',
#  'believed',
#  'deservedly',
#  'Highbury',
#  'sufficiently',
#  'belonging',
#  'prospects',
#  'Churchill',
#  'Highbury',
#  'curiosity',
#  'prevailed',
#  'compliment',
#  'returned',
#  'achieved',
#  'marriage',
#  'generally',
#  'proposed',
#  'attention',
#  'dissentient',
#  'returned',
#  'Churchill',
#  'strengthened',
#  'understood',
#  'occasion',
#  'Highbury',
#  'included',
#  'handsome',
#  'received',
#  'handsome',
#  'Churchill',
#  'understand',
#  'handsome',
#  'Woodhouse',
#  'Woodhouse',
#  'handsome',
#  'favourable',
#  'pleasing',
#  'attention',
#  'irresistible',
#  'addition',
#  'expression',
#  'congratulation',
#  'marriage',
#  'fortunate',
#  'fortunate',
#  'separation',
#  'friendship',
#  'pleasure',
#  'suffering',
#  'companionableness',
#  'character',
#  'situation',
#  'difficulties',
#  'privations',
#  'distance',
#  'Randalls',
#  'Hartfield',
#  'convenient',
#  'solitary',
#  'disposition',
#  'circumstances',
#  'approaching',
#  'hindrance',
#  'spending',
#  'evenings',
#  'together',
#  'situation',
#  'altogether',
#  'gratitude',
#  'satisfaction',
#  'satisfaction',
#  'cheerful',
#  'enjoyment',
#  'apparent',
#  'sometimes',
#  'surprize',
#  'Randalls',
#  'domestic',
#  'attended',
#  'pleasant',
#  'carriage',
#  'Woodhouse',
#  'recovering',
#  'likelihood',
#  'alleviation',
#  'Woodhouse',
#  'compliments',
#  'neighbours',
#  'sorrowful',
#  'distress',
#  'different',
#  'unwholesome',
#  'regarded',
#  'therefore',
#  'earnestly',
#  'dissuade',
#  'earnestly',
#  'consulting',
#  'apothecary',
#  'intelligent',
#  'gentlemanlike',
#  'frequent',
#  'comforts',
#  'Woodhouse',
#  'acknowledge',
#  'inclination',
#  'certainly',
#  'disagree',
#  'moderately',
#  'confirmation',
#  'Woodhouse',
#  'influence',
#  'benevolent',
#  'Highbury',
#  'Woodhouse',
#  'Woodhouse',
#  'residence',
#  'Hartfield',
#  'daughter',
#  'intercourse',
#  'families',
#  'acquaintance',
#  'Fortunately',
#  'Highbury',
#  'including',
#  'Randalls',
#  'adjoining',
#  'Knightley',
#  'comprehended',
#  'unfrequently',
#  'persuasion',
#  'preferred',
#  'scarcely',
#  'standing',
#  'Knightley',
#  'privilege',
#  'exchanging',
#  'solitude',
#  'elegancies',
#  'Woodhouse',
#  'daughter',
#  'invitation',
#  'Hartfield',
#  'Woodhouse',
#  'hardship',
#  'grievance',
#  'Highbury',
#  'quadrille',
#  'daughter',
#  'considered',
#  'harmless',
#  'untoward',
#  'circumstances',
#  'daughter',
#  'uncommon',
#  'popularity',
#  'handsome',
#  'predicament',
#  'intellectual',
#  'superiority',
#  'atonement',
#  'frighten',
#  'cleverness',
#  'distinction',
#  'endeavour',
#  'possible',
#  'universal',
#  'contented',
#  'interested',
#  'happiness',
#  'quicksighted',
#  'fortunate',
#  'creature',
#  'surrounded',
#  'blessings',
#  'excellent',
#  'neighbours',
#  'simplicity',
#  'cheerfulness',
#  'contented',
#  'grateful',
#  'recommendation',
#  'felicity',
#  'Woodhouse',
#  'communications',
#  'harmless',
#  'mistress',
#  'seminary',
#  'establishment',
#  'professed',
#  'sentences',
#  'nonsense',
#  'acquirements',
#  'morality',
#  'principles',
#  'enormous',
#  'fashioned',
#  'Boarding',
#  'reasonable',
#  'quantity',
#  'accomplishments',
#  'reasonable',
#  'scramble',
#  'themselves',
#  'education',
#  'prodigies',
#  'deservedly',
#  'Highbury',
#  'reckoned',
#  'particularly',
#  'children',
#  'wholesome',
#  'chilblains',
#  'motherly',
#  'entitled',
#  'occasional',
#  'formerly',
#  'Woodhouse',
#  'kindness',
#  'particular',
#  'whenever',
#  'sixpences',
#  'fireside',
#  'frequently',
#  'concerned',
#  'delighted',
#  'comfortable',
#  'contriving',
#  'prosings',
#  'evenings',
#  'fearfully',
#  'anticipated',
#  'requesting',
#  'respectful',
#  'seventeen',
#  'interest',
#  'gracious',
#  'invitation',
#  'returned',
#  'mistress',
#  'daughter',
#  'somebody',
#  'Somebody',
#  'somebody',
#  'condition',
#  'generally',
#  'acquired',
#  'Highbury',
#  'returned',
#  'happened',
#  'particularly',
#  'features',
#  'sweetness',
#  'determined',
#  'continue',
#  'acquaintance',
#  'remarkably',
#  'conversation',
#  'altogether',
#  'engaging',
#  'inconveniently',
#  'unwilling',
#  'becoming',
#  'deference',
#  'pleasantly',
#  'grateful',
#  'admitted',
#  'Hartfield',
#  'artlessly',
#  'impressed',
#  'appearance',
#  'superior',
#  'encouragement',
#  'Encouragement',
#  'inferior',
#  'Highbury',
#  'connexions',
#  'acquaintance',
#  'unworthy',
#  'character',
#  'Knightley',
#  'residing',
#  'creditably',
#  'believed',
#  'Knightley',
#  'unpolished',
#  'intimates',
#  'knowledge',
#  'elegance',
#  'acquaintance',
#  'introduce',
#  'opinions',
#  'interesting',
#  'certainly',
#  'undertaking',
#  'becoming',
#  'situation',
#  'admiring',
#  'listening',
#  'betweens',
#  'forwards',
#  'alacrity',
#  'indifferent',
#  'attentively',
#  'delighted',
#  'recommend',
#  'scalloped',
#  'acceptable',
#  'scruples',
#  'occasions',
#  'Woodhouses',
#  'feelings',
#  'conviction',
#  'unwholesome',
#  'hospitality',
#  'welcomed',
#  'visitors',
#  'thorough',
#  'approbation',
#  'recommend',
#  'constrain',
#  'comfortably',
#  'clearing',
#  'venturing',
#  'unwholesome',
#  'understands',
#  'recommend',
#  '_little_',
#  'unwholesome',
#  'preserves',
#  'disagree',
#  'supplied',
#  'visitors',
#  'satisfactory',
#  'particular',
#  'pleasure',
#  'happiness',
#  'intentions',
#  'Woodhouse',
#  'personage',
#  'Highbury',
#  'prospect',
#  'introduction',
#  'pleasure',
#  'grateful',
#  'gratified',
#  'feelings',
#  'delighted',
#  'affability',
#  'Woodhouse',
#  'actually',
#  'intimacy',
#  'Hartfield',
#  'inviting',
#  'encouraging',
#  'acquaintance',
#  'increased',
#  'satisfaction',
#  'companion',
#  'foreseen',
#  'important',
#  'shrubbery',
#  'divisions',
#  'sufficed',
#  'marriage',
#  'exercise',
#  'confined',
#  'ventured',
#  'Randalls',
#  'pleasant',
#  'therefore',
#  'valuable',
#  'addition',
#  'privileges',
#  'approved',
#  'confirmed',
#  'certainly',
#  'grateful',
#  'disposition',
#  'desiring',
#  'attachment',
#  'inclination',
#  'appreciating',
#  'strength',
#  'understanding',
#  'expected',
#  'Altogether',
#  'convinced',
#  'something',
#  'required',
#  'question',
#  'different',
#  'sentiment',
#  'distinct',
#  'independent',
#  'gratitude',
#  'attempts',
#  'usefulness',
#  'endeavour',
#  'questions',
#  'situation',
#  'discovered',
#  'penetration',
#  'satisfied',
#  'teachers',
#  'naturally',
#  'conversation',
#  'acquaintance',
#  'occupied',
#  'thoughts',
#  'pleasures',
#  'describe',
#  'comforts',
#  'encouraged',
#  'talkativeness',
#  'enjoying',
#  'youthful',
#  'simplicity',
#  'exultation',
#  'parlours',
#  'parlours',
#  'Alderneys',
#  'handsome',
#  'handsome',
#  'thinking',
#  'immediate',
#  'understand',
#  'feelings',
#  'fancying',
#  'daughter',
#  'together',
#  'appeared',
#  'narrative',
#  'mentioned',
#  'approbation',
#  'something',
#  'hospitality',
#  'kindness',
#  'required',
#  'inspiriting',
#  'questions',
#  'increased',
#  'particularly',
#  'evidently',
#  'moonlight',
#  'humoured',
#  'obliging',
#  'obliging',
#  'shepherd',
#  'believed',
#  'understood',
#  'believed',
#  'impossible',
#  'therefore',
#  'whenever',
#  '_wanted_',
#  'beautiful',
#  'teachers',
#  'Richardson',
#  'information',
#  'business',
#  'Agricultural',
#  'sometimes',
#  'something',
#  'Extracts',
#  'entertaining',
#  'Wakefield',
#  'Children',
#  'mentioned',
#  'determined',
#  'question',
#  'handsome',
#  'handsome',
#  'Highbury',
#  'Kingston',
#  'horseback',
#  'curiosity',
#  'yeomanry',
#  'precisely',
#  'creditable',
#  'appearance',
#  'interest',
#  'families',
#  'therefore',
#  'observed',
#  'respectable',
#  'birthday',
#  'fortnight',
#  'difference',
#  'perfectly',
#  'comfortable',
#  'probably',
#  'desirable',
#  'Woodhouse',
#  'independence',
#  'entirely',
#  'beforehand',
#  'Whatever',
#  'whatever',
#  'property',
#  'employed',
#  'diligence',
#  'impossible',
#  'realised',
#  'comfortably',
#  'whenever',
#  'acquainted',
#  'superior',
#  'education',
#  'altogether',
#  'objected',
#  'misfortune',
#  'particularly',
#  'associates',
#  'gentleman',
#  'daughter',
#  'pleasure',
#  'degrading',
#  'Hartfield',
#  'Woodhouse',
#  'understand',
#  'influence',
#  'established',
#  'independent',
#  'Hartfield',
#  'Woodhouse',
#  'permanently',
#  'connected',
#  'advisable',
#  'acquaintance',
#  'therefore',
#  'intimacy',
#  'acquainted',
#  'probably',
#  'daughter',
#  'education',
#  'education',
#  'acquaintance',
#  'especially',
#  'Elizabeth',
#  'educated',
#  'ignorant',
#  'certainly',
#  'fluctuations',
#  'alarming',
#  'symptoms',
#  'difficulty',
#  'friendly',
#  'arrangement',
#  'respectfully',
#  'unfeigned',
#  'satisfaction',
#  'companion',
#  'opportunity',
#  'together',
#  'sufficiently',
#  'acquainted',
#  'appearance',
#  'sensible',
#  'advantage',
#  'contrasted',
#  'gentlemen',
#  'inclination',
#  'insensible',
#  'voluntarily',
#  'gentleness',
#  'admiration',
#  'remained',
#  'together',
#  'Woodhouse',
#  ...]

# %% [markdown]
# ### Exercise 1.3
# *Find the words that are longer than 7 characters and occur more than 7 times in the complete Gutenberg corpus.*

# %%
counted = collections.Counter(gutenbergwords)
counted['Woodhouse']
[w for w in gutenbergwords if len(w) > 7 and counted[w] >= 7]
# Out:
# ['Woodhouse',
#  'handsome',
#  'comfortable',
#  'disposition',
#  'blessings',
#  'existence',
#  'distress',
#  'youngest',
#  'daughters',
#  'affectionate',
#  'indulgent',
#  'consequence',
#  'marriage',
#  'mistress',
#  'remembrance',
#  'caresses',
#  'supplied',
#  'excellent',
#  'governess',
#  'affection',
#  'Woodhouse',
#  'governess',
#  'daughters',
#  'particularly',
#  'intimacy',
#  'governess',
#  'mildness',
#  'restraint',
#  'authority',
#  'together',
#  'mutually',
#  'attached',
#  'judgment',
#  'directed',
#  'situation',
#  'disposition',
#  'threatened',
#  'enjoyments',
#  'disagreeable',
#  'consciousness',
#  'mournful',
#  'continuance',
#  'together',
#  'prospect',
#  'composed',
#  'happiness',
#  'unexceptionable',
#  'character',
#  'suitable',
#  'pleasant',
#  'satisfaction',
#  'considering',
#  'generous',
#  'friendship',
#  'promoted',
#  'recalled',
#  'kindness',
#  'kindness',
#  'affection',
#  'childhood',
#  'gratitude',
#  'intercourse',
#  'unreserve',
#  'followed',
#  'Isabella',
#  'marriage',
#  'recollection',
#  'companion',
#  'possessed',
#  'intelligent',
#  'informed',
#  'interested',
#  'concerns',
#  'peculiarly',
#  'interested',
#  'pleasure',
#  'affection',
#  'difference',
#  'advantages',
#  'domestic',
#  'suffering',
#  'intellectual',
#  'solitude',
#  'companion',
#  'conversation',
#  'rational',
#  'disparity',
#  'Woodhouse',
#  'increased',
#  'constitution',
#  'activity',
#  'everywhere',
#  'friendliness',
#  'recommended',
#  'comparatively',
#  'matrimony',
#  'November',
#  'struggled',
#  'Hartfield',
#  'Christmas',
#  'Isabella',
#  'children',
#  'pleasant',
#  'Highbury',
#  'populous',
#  'Hartfield',
#  'separate',
#  'shrubberies',
#  'afforded',
#  'consequence',
#  'acquaintance',
#  'universally',
#  'accepted',
#  'melancholy',
#  'impossible',
#  'necessary',
#  'cheerful',
#  'required',
#  'depressed',
#  'disagreeable',
#  'reconciled',
#  'daughter',
#  'marrying',
#  'compassion',
#  'entirely',
#  'affection',
#  'selfishness',
#  'differently',
#  'disposed',
#  'Hartfield',
#  'cheerfully',
#  'thoughts',
#  'impossible',
#  'humoured',
#  'pleasant',
#  'excellent',
#  'thoroughly',
#  'deserves',
#  'advantage',
#  'Randalls',
#  'distance',
#  'carriage',
#  'carriage',
#  'Randalls',
#  'daughter',
#  'anywhere',
#  'mentioned',
#  'slighted',
#  'Whenever',
#  'needlework',
#  'excellent',
#  'somebody',
#  'Whenever',
#  'daughter',
#  'exertions',
#  'maintain',
#  'tolerably',
#  'attacked',
#  'immediately',
#  'afterwards',
#  'unnecessary',
#  'Knightley',
#  'sensible',
#  'intimate',
#  'particularly',
#  'connected',
#  'Isabella',
#  'Highbury',
#  'frequent',
#  'directly',
#  'connexions',
#  'returned',
#  'Hartfield',
#  'Brunswick',
#  'circumstance',
#  'animated',
#  'Woodhouse',
#  'Knightley',
#  'cheerful',
#  'inquiries',
#  'Isabella',
#  'children',
#  'answered',
#  'Woodhouse',
#  'gratefully',
#  'observed',
#  'Knightley',
#  'shocking',
#  'beautiful',
#  'moonlight',
#  'surprising',
#  'dreadfully',
#  'breakfast',
#  'congratulations',
#  'tolerably',
#  'business',
#  'Woodhouse',
#  'possibly',
#  'question',
#  'dependence',
#  'independence',
#  'fanciful',
#  'troublesome',
#  'creature',
#  'certainly',
#  'Woodhouse',
#  'sometimes',
#  'fanciful',
#  'troublesome',
#  'Knightley',
#  'horrible',
#  'Knightley',
#  'Knightley',
#  'Woodhouse',
#  'particularly',
#  'agreeable',
#  'circumstance',
#  'Knightley',
#  'reflection',
#  'punctual',
#  'Knightley',
#  'impossible',
#  'companion',
#  'Knightley',
#  'marriage',
#  'advantage',
#  'acceptable',
#  'important',
#  'comfortable',
#  'provision',
#  'therefore',
#  'pleasure',
#  'forgotten',
#  'considerable',
#  'Knightley',
#  'whatever',
#  'greatest',
#  'amusement',
#  'perfectly',
#  'comfortable',
#  'constantly',
#  'occupied',
#  'business',
#  'acceptable',
#  'wherever',
#  'cheerful',
#  'certainly',
#  'nonsense',
#  'believed',
#  'Broadway',
#  'gallantry',
#  'borrowed',
#  'instance',
#  'understand',
#  'Knightley',
#  'endeavour',
#  'properly',
#  'delicately',
#  'endeavouring',
#  'marriage',
#  'employment',
#  'planning',
#  'yourself',
#  'yourself',
#  'afterwards',
#  'pleasure',
#  'entirely',
#  'pictures',
#  'something',
#  'promoted',
#  'Hartfield',
#  'comprehend',
#  'rational',
#  'unaffected',
#  'concerns',
#  'yourself',
#  'interference',
#  'rejoined',
#  'Woodhouse',
#  'understanding',
#  'grievously',
#  'Highbury',
#  'deserves',
#  'comfortably',
#  'attention',
#  'Knightley',
#  'pleasure',
#  'Knightley',
#  'laughing',
#  'entirely',
#  'Highbury',
#  'respectable',
#  'generations',
#  'gentility',
#  'property',
#  'received',
#  'education',
#  'succeeding',
#  'independence',
#  'indisposed',
#  'pursuits',
#  'brothers',
#  'satisfied',
#  'cheerful',
#  'entering',
#  'favourite',
#  'military',
#  'introduced',
#  'Churchill',
#  'Yorkshire',
#  'Churchill',
#  'surprized',
#  'importance',
#  'connexion',
#  'Churchill',
#  'proportion',
#  'marriage',
#  'infinite',
#  'mortification',
#  'Churchill',
#  'connexion',
#  'happiness',
#  'goodness',
#  'resolution',
#  'unreasonable',
#  'unreasonable',
#  'comparison',
#  'Enscombe',
#  'Churchill',
#  'Enscombe',
#  'considered',
#  'especially',
#  'Churchills',
#  'marriage',
#  'maintain',
#  'relieved',
#  'additional',
#  'lingering',
#  'reconciliation',
#  'Churchill',
#  'children',
#  'creature',
#  'scruples',
#  'reluctance',
#  'supposed',
#  'overcome',
#  'considerations',
#  'Churchills',
#  'situation',
#  'complete',
#  'desirable',
#  'brothers',
#  'established',
#  'afforded',
#  'favourable',
#  'employment',
#  'Highbury',
#  'occupation',
#  'pleasures',
#  'eighteen',
#  'cheerfully',
#  'realised',
#  'purchase',
#  'adjoining',
#  'Highbury',
#  'according',
#  'friendly',
#  'disposition',
#  'influence',
#  'influence',
#  'determination',
#  'settling',
#  'purchase',
#  'Randalls',
#  'Randalls',
#  'steadily',
#  'accomplished',
#  'obtained',
#  'beginning',
#  'existence',
#  'probability',
#  'happiness',
#  'marriage',
#  'delightful',
#  'pleasantest',
#  'gratitude',
#  'adoption',
#  'Churchill',
#  'unlikely',
#  'therefore',
#  'assistance',
#  'apprehension',
#  'capricious',
#  'governed',
#  'entirely',
#  'believed',
#  'Highbury',
#  'sufficiently',
#  'belonging',
#  'prospects',
#  'Churchill',
#  'Highbury',
#  'curiosity',
#  'prevailed',
#  'compliment',
#  'returned',
#  'achieved',
#  'marriage',
#  'generally',
#  'proposed',
#  'attention',
#  'returned',
#  'Churchill',
#  'strengthened',
#  'understood',
#  'occasion',
#  'Highbury',
#  'included',
#  'handsome',
#  'received',
#  'handsome',
#  'Churchill',
#  'understand',
#  'handsome',
#  'Woodhouse',
#  'Woodhouse',
#  'handsome',
#  'favourable',
#  'pleasing',
#  'attention',
#  'irresistible',
#  'addition',
#  'expression',
#  'marriage',
#  'fortunate',
#  'fortunate',
#  'separation',
#  'friendship',
#  'pleasure',
#  'suffering',
#  'character',
#  'situation',
#  'difficulties',
#  'distance',
#  'Randalls',
#  'Hartfield',
#  'convenient',
#  'solitary',
#  'disposition',
#  'circumstances',
#  'approaching',
#  'spending',
#  'evenings',
#  'together',
#  'situation',
#  'altogether',
#  'gratitude',
#  'satisfaction',
#  'satisfaction',
#  'cheerful',
#  'enjoyment',
#  'apparent',
#  'sometimes',
#  'surprize',
#  'Randalls',
#  'domestic',
#  'attended',
#  'pleasant',
#  'carriage',
#  'Woodhouse',
#  'recovering',
#  'Woodhouse',
#  'compliments',
#  'neighbours',
#  'sorrowful',
#  'distress',
#  'different',
#  'unwholesome',
#  'regarded',
#  'therefore',
#  'earnestly',
#  'dissuade',
#  'earnestly',
#  'consulting',
#  'apothecary',
#  'intelligent',
#  'gentlemanlike',
#  'frequent',
#  'comforts',
#  'Woodhouse',
#  'acknowledge',
#  'inclination',
#  'certainly',
#  'disagree',
#  'moderately',
#  'confirmation',
#  'Woodhouse',
#  'influence',
#  'benevolent',
#  'Highbury',
#  'Woodhouse',
#  'Woodhouse',
#  'residence',
#  'Hartfield',
#  'daughter',
#  'intercourse',
#  'families',
#  'acquaintance',
#  'Highbury',
#  'including',
#  'Randalls',
#  'adjoining',
#  'Knightley',
#  'comprehended',
#  'persuasion',
#  'preferred',
#  'scarcely',
#  'standing',
#  'Knightley',
#  'privilege',
#  'solitude',
#  'Woodhouse',
#  'daughter',
#  'invitation',
#  'Hartfield',
#  'Woodhouse',
#  'hardship',
#  'grievance',
#  'Highbury',
#  'daughter',
#  'considered',
#  'harmless',
#  'circumstances',
#  'daughter',
#  'uncommon',
#  'popularity',
#  'handsome',
#  'intellectual',
#  'superiority',
#  'atonement',
#  'frighten',
#  'distinction',
#  'endeavour',
#  'possible',
#  'universal',
#  'contented',
#  'interested',
#  'happiness',
#  'fortunate',
#  'creature',
#  'surrounded',
#  'blessings',
#  'excellent',
#  'neighbours',
#  'simplicity',
#  'cheerfulness',
#  'contented',
#  'grateful',
#  'recommendation',
#  'felicity',
#  'Woodhouse',
#  'communications',
#  'harmless',
#  'mistress',
#  'establishment',
#  'professed',
#  'sentences',
#  'nonsense',
#  'morality',
#  'principles',
#  'enormous',
#  'fashioned',
#  'reasonable',
#  'quantity',
#  'accomplishments',
#  'reasonable',
#  'themselves',
#  'education',
#  'Highbury',
#  'reckoned',
#  'particularly',
#  'children',
#  'wholesome',
#  'entitled',
#  'occasional',
#  'formerly',
#  'Woodhouse',
#  'kindness',
#  'particular',
#  'whenever',
#  'fireside',
#  'frequently',
#  'concerned',
#  'delighted',
#  'comfortable',
#  'contriving',
#  'evenings',
#  'fearfully',
#  'anticipated',
#  'respectful',
#  'seventeen',
#  'interest',
#  'gracious',
#  'invitation',
#  'returned',
#  'mistress',
#  'daughter',
#  'somebody',
#  'Somebody',
#  'somebody',
#  'condition',
#  'generally',
#  'acquired',
#  'Highbury',
#  'returned',
#  'happened',
#  'particularly',
#  'features',
#  'sweetness',
#  'determined',
#  'continue',
#  'acquaintance',
#  'remarkably',
#  'conversation',
#  'altogether',
#  'engaging',
#  'unwilling',
#  'becoming',
#  'deference',
#  'pleasantly',
#  'grateful',
#  'admitted',
#  'Hartfield',
#  'impressed',
#  'appearance',
#  'superior',
#  'encouragement',
#  'inferior',
#  'Highbury',
#  'connexions',
#  'acquaintance',
#  'unworthy',
#  'character',
#  'Knightley',
#  'residing',
#  'believed',
#  'Knightley',
#  'knowledge',
#  'elegance',
#  'acquaintance',
#  'introduce',
#  'opinions',
#  'interesting',
#  'certainly',
#  'becoming',
#  'situation',
#  'admiring',
#  'listening',
#  'forwards',
#  'alacrity',
#  'indifferent',
#  'attentively',
#  'delighted',
#  'recommend',
#  'acceptable',
#  'scruples',
#  'occasions',
#  'feelings',
#  'conviction',
#  'unwholesome',
#  'hospitality',
#  'welcomed',
#  'visitors',
#  'thorough',
#  'approbation',
#  'recommend',
#  'comfortably',
#  'clearing',
#  'venturing',
#  'unwholesome',
#  'understands',
#  'recommend',
#  'unwholesome',
#  'disagree',
#  'supplied',
#  'visitors',
#  'satisfactory',
#  'particular',
#  'pleasure',
#  'happiness',
#  'intentions',
#  'Woodhouse',
#  'Highbury',
#  'prospect',
#  'introduction',
#  'pleasure',
#  'grateful',
#  'gratified',
#  'feelings',
#  'delighted',
#  'Woodhouse',
#  'actually',
#  'intimacy',
#  'Hartfield',
#  'inviting',
#  'encouraging',
#  'acquaintance',
#  'increased',
#  'satisfaction',
#  'companion',
#  'foreseen',
#  'important',
#  'shrubbery',
#  'divisions',
#  'sufficed',
#  'marriage',
#  'exercise',
#  'confined',
#  'ventured',
#  'Randalls',
#  'pleasant',
#  'therefore',
#  'valuable',
#  'addition',
#  'approved',
#  'confirmed',
#  'certainly',
#  'grateful',
#  'disposition',
#  'desiring',
#  'attachment',
#  'inclination',
#  'strength',
#  'understanding',
#  'expected',
#  'convinced',
#  'something',
#  'required',
#  'question',
#  'different',
#  'sentiment',
#  'distinct',
#  'independent',
#  'gratitude',
#  'attempts',
#  'usefulness',
#  'endeavour',
#  'questions',
#  'situation',
#  'discovered',
#  'penetration',
#  'satisfied',
#  'teachers',
#  'naturally',
#  'conversation',
#  'acquaintance',
#  'occupied',
#  'thoughts',
#  'pleasures',
#  'describe',
#  'comforts',
#  'encouraged',
#  'enjoying',
#  'youthful',
#  'simplicity',
#  'exultation',
#  'handsome',
#  'handsome',
#  'thinking',
#  'immediate',
#  'understand',
#  'feelings',
#  'fancying',
#  'daughter',
#  'together',
#  'appeared',
#  'narrative',
#  'mentioned',
#  'approbation',
#  'something',
#  'hospitality',
#  'kindness',
#  'required',
#  'questions',
#  'increased',
#  'particularly',
#  'evidently',
#  'moonlight',
#  'humoured',
#  'obliging',
#  'obliging',
#  'shepherd',
#  'believed',
#  'understood',
#  'believed',
#  'impossible',
#  'therefore',
#  'whenever',
#  'beautiful',
#  'teachers',
#  'information',
#  'business',
#  'sometimes',
#  'something',
#  'entertaining',
#  'Children',
#  'mentioned',
#  'determined',
#  'question',
#  'handsome',
#  'handsome',
#  'Highbury',
#  'Kingston',
#  'horseback',
#  'curiosity',
#  'precisely',
#  'creditable',
#  'appearance',
#  'interest',
#  'families',
#  'therefore',
#  'observed',
#  'respectable',
#  'birthday',
#  'fortnight',
#  'difference',
#  'perfectly',
#  'comfortable',
#  'probably',
#  'desirable',
#  'Woodhouse',
#  'independence',
#  'entirely',
#  'beforehand',
#  'Whatever',
#  'whatever',
#  'property',
#  'employed',
#  'diligence',
#  'impossible',
#  'realised',
#  'comfortably',
#  'whenever',
#  'acquainted',
#  'superior',
#  'education',
#  'altogether',
#  'objected',
#  'misfortune',
#  'particularly',
#  'associates',
#  'gentleman',
#  'daughter',
#  'pleasure',
#  'Hartfield',
#  'Woodhouse',
#  'understand',
#  'influence',
#  'established',
#  'independent',
#  'Hartfield',
#  'Woodhouse',
#  'permanently',
#  'connected',
#  'advisable',
#  'acquaintance',
#  'therefore',
#  'intimacy',
#  'acquainted',
#  'probably',
#  'daughter',
#  'education',
#  'education',
#  'acquaintance',
#  'especially',
#  'Elizabeth',
#  'educated',
#  'ignorant',
#  'certainly',
#  'alarming',
#  'symptoms',
#  'difficulty',
#  'friendly',
#  'arrangement',
#  'respectfully',
#  'unfeigned',
#  'satisfaction',
#  'companion',
#  'opportunity',
#  'together',
#  'sufficiently',
#  'acquainted',
#  'appearance',
#  'sensible',
#  'advantage',
#  'contrasted',
#  'gentlemen',
#  'inclination',
#  'insensible',
#  'voluntarily',
#  'gentleness',
#  'admiration',
#  'remained',
#  'together',
#  'Woodhouse',
#  'Woodhouse',
#  'happening',
#  'Randalls',
#  'Randalls',
#  'Kingston',
#  'Woodhouse',
#  'expected',
#  'undoubtedly',
#  'remarkably',
#  'compared',
#  'gentility',
#  'imagined',
#  'gentility',
#  'mortified',
#  'gentlemen',
#  'acquaintance',
#  'repeatedly',
#  'gentlemen',
#  'yourself',
#  'difference',
#  'Hartfield',
#  'specimens',
#  'educated',
#  'surprized',
#  'perceiving',
#  'inferior',
#  'creature',
#  'wondering',
#  'yourself',
#  'agreeable',
#  'Certainly',
#  'Knightley',
#  'Knightley',
#  'difference',
#  'Knightley',
#  'Knightley',
#  'remarkably',
#  'Knightley',
#  'gentleman',
#  'carrying',
#  'themselves',
#  'speaking',
#  'difference',
#  'difference',
#  'valuable',
#  'important',
#  'disgusting',
#  'awkwardness',
#  'detestable',
#  'solemnly',
#  'completely',
#  'appearances',
#  'thinking',
#  'business',
#  'circumstance',
#  'forgetting',
#  'recommended',
#  'illiterate',
#  'remember',
#  'displeasure',
#  'therefore',
#  'beginning',
#  'superior',
#  'Knightley',
#  'gentleness',
#  'openness',
#  'quickness',
#  'Knightley',
#  'downright',
#  'commanding',
#  'situation',
#  'contrary',
#  'recommended',
#  'humoured',
#  'cheerful',
#  'obliging',
#  'particularly',
#  'additional',
#  'softness',
#  'repeated',
#  'personal',
#  'agreeable',
#  'excellent',
#  'desirable',
#  'probable',
#  'planning',
#  'equalled',
#  'Hartfield',
#  'considered',
#  'situation',
#  'suitable',
#  'gentleman',
#  'connexions',
#  'doubtful',
#  'comfortable',
#  ...]

# %% [markdown]
# ### Exercise 1.4
# *Find the average number of words across the documents of the NLTK Gutenberg corpus.*

# %%
len(nltk.corpus.gutenberg.words())/len(nltk.corpus.gutenberg.fileids())
# Out:
# 145645.16666666666

# %% [markdown]
# ### Exercise 1.5
# *Find the Gutenberg document that has the longest average word length.*

# %%
the_text = ""
largest_average = 0
for text in nltk.corpus.gutenberg.fileids():
    num_chars = len(nltk.corpus.gutenberg.raw(text))
    num_words = len(nltk.corpus.gutenberg.words(text))
    average = num_chars/num_words
    if(average > largest_average):
        largest_average=average
        the_text = text
print(largest_average)
print(the_text)
# Out:
# 4.835734572682675
# milton-paradise.txt

# %% [markdown]
# ### Exercise 1.6
# *Find the 10 most frequent bigrams in the entire Gutenberg corpus.*

# %%
# Out:
# [((',', 'and'), 41294),
#  (('of', 'the'), 18912),
#  (('in', 'the'), 9793),
#  (("'", 's'), 9781),
#  ((';', 'and'), 7559),
#  (('and', 'the'), 6432),
#  (('the', 'LORD'), 5964),
#  ((',', 'the'), 5957),
#  ((',', 'I'), 5677),
#  ((',', 'that'), 5352)]

# %% [markdown]
# ### Exercise 1.7
# *Find the most frequent bigram that begins with "Moby" in Herman Melville's "Moby Dick".*

# %%
moby = nltk.corpus.gutenberg.words('melville-moby_dick.txt')
moby_bigrams = nltk.bigrams(moby)
return_this = [b for b in moby_bigrams if(b[0] == "Moby")]
bigramsCount = collections.Counter(return_this)
bigramsCount.most_common(10)
# Out:
# [(('Moby', 'Dick'), 83), (('Moby', '-'), 1)]

# %% [markdown]
# # 2. Text Preprocessing with NLTK
# The following exercises will ask several questions about tokens, stems, and parts of speech.
#
# ### Exercise 2.1
# *What is the sentence with the largest number of tokens in Austen's "Emma"?*

# %%
emma = nltk.corpus.gutenberg.raw('austen-emma.txt')
longest_sentence = ""
longest_sentence_length = 0
for s in nltk.sent_tokenize(emma):
    for index,w in enumerate(nltk.word_tokenize(s), start=1):
        if(index > longest_sentence_length):
            longest_sentence = s
            longest_sentence_length = index
print(longest_sentence)
longest_sentence_length
# Out:
# While he lived, it must be only an engagement;
# but she flattered herself, that if divested of the danger of
# drawing her away, it might become an increase of comfort to him.--
# How to do her best by Harriet, was of more difficult decision;--
# how to spare her from any unnecessary pain; how to make
# her any possible atonement; how to appear least her enemy?--
# On these subjects, her perplexity and distress were very great--
# and her mind had to pass again and again through every bitter
# reproach and sorrowful regret that had ever surrounded it.--
# She could only resolve at last, that she would still avoid a
# meeting with her, and communicate all that need be told by letter;
# that it would be inexpressibly desirable to have her removed just
# now for a time from Highbury, and--indulging in one scheme more--
# nearly resolve, that it might be practicable to get an invitation
# for her to Brunswick Square.--Isabella had been pleased with Harriet;
# and a few weeks spent in London must give her some amusement.--
# She did not think it in Harriet's nature to escape being benefited
# by novelty and variety, by the streets, the shops, and the children.--
# At any rate, it would be a proof of attention and kindness in herself,
# from whom every thing was due; a separation for the present; an averting
# of the evil day, when they must all be together again.
# 275

# %% [markdown]
# ### Exercise 2.2
# *What is the most frequent part of speech in Austen's "Emma"?*

# %%
text_sent_tokens = [nltk.word_tokenize(s) for s in nltk.sent_tokenize(emma)]
emma_tagged_sents = [nltk.pos_tag(s) for s in text_sent_tokens]
tuple_array = []
for s in emma_tagged_sents:
    for w in s:
        tuple_array.append(w[1])
tagged = collections.Counter(tuple_array)
tagged.most_common(10)
# Out:
# [('NN', 19330),
#  ('IN', 17880),
#  ('PRP', 15619),
#  ('RB', 12997),
#  ('DT', 12743),
#  (',', 12016),
#  ('JJ', 10249),
#  ('NNP', 9095),
#  ('VBD', 9049),
#  ('VB', 8941)]

# %% [markdown]
# ### Exercise 2.3
# *What is the number of distinct stems in Austen's "Emma"?*

# %%
stemer = nltk.PorterStemmer()
stemlist = [stemer.stem(w) for w in nltk.word_tokenize(emma)]
distinctstems = set(stemlist)
len(distinctstems)
distinctstems
# Out:
# {'condit',
#  'encumb',
#  'screen',
#  'dearli',
#  'naivet',
#  'prejudic',
#  'forbid',
#  'immediately.',
#  'anecdot',
#  'father.',
#  'deem',
#  'inde',
#  '_refused_',
#  'she.',
#  'constern',
#  'home-bak',
#  'busi',
#  'indignantli',
#  'train',
#  'cobham',
#  'depart',
#  'unreserv',
#  "emma'",
#  'frame',
#  'agreement',
#  'allus',
#  'unknown.',
#  'featur',
#  'bring',
#  'far',
#  'scarlet',
#  'grammarian',
#  'basket',
#  'advanc',
#  'assert',
#  'incident',
#  'divin',
#  'wife.',
#  "neighbours'",
#  'uncertainti',
#  'convinc',
#  'foot-pac',
#  'literari',
#  'mrs.',
#  'warm-heart',
#  'I',
#  'repres',
#  'celleri',
#  'thorough',
#  'law',
#  'cotton',
#  'map',
#  'lowest',
#  'sitters-bi',
#  'backward',
#  'another.',
#  'ah',
#  'open-heart',
#  'incomprehens',
#  'partner',
#  'probabl',
#  'indebt',
#  'infanc',
#  'lazi',
#  'undertook',
#  'wet.',
#  'pain.',
#  'slap',
#  'fever',
#  'thrive',
#  'let',
#  '_dissolved_',
#  'hardli',
#  '_ten_',
#  'happili',
#  'ago',
#  'aim',
#  'deplor',
#  'never',
#  'surprize.',
#  'enough',
#  'pomp',
#  'happen',
#  'hall',
#  'dew',
#  'lady-lik',
#  'speed',
#  'reviv',
#  'storeroom',
#  'sweep-gat',
#  're-urg',
#  'caprici',
#  'social',
#  '_he_',
#  'eccentr',
#  'bia',
#  'politeness.',
#  'blinder',
#  'justic',
#  'gentil',
#  'white',
#  'neighbours.',
#  'difficult',
#  'penit',
#  'kill',
#  'explan',
#  'of.',
#  'elderli',
#  'unsuspici',
#  'well-known',
#  'road.',
#  'greater',
#  'except',
#  'saunter',
#  'him.',
#  'fag',
#  'about',
#  'candidli',
#  'memorandum',
#  'par',
#  'swisserland',
#  'briefli',
#  'dash',
#  'interior',
#  'disinterest',
#  'make.',
#  'smiled.',
#  'true.',
#  'sunshin',
#  'vex',
#  'becam',
#  'activ',
#  '_way_',
#  'graham',
#  'societi',
#  'ambit',
#  'period',
#  'handwrit',
#  'otway',
#  'self-controul',
#  'stupidest',
#  'confound',
#  'colonel',
#  'overhear',
#  'vouchsaf',
#  'imposs',
#  'loin',
#  'alon',
#  'companion',
#  'cipher',
#  'cruel',
#  'bond',
#  '_taylor_',
#  '_now_',
#  'perry.',
#  'workbasket',
#  'banish',
#  'shook',
#  'gave',
#  'extent',
#  'mock',
#  'currant',
#  'supplant',
#  'fondli',
#  'unnecessarili',
#  'tall',
#  'forti',
#  'improp',
#  'walnut',
#  'forgotten',
#  'dispirit',
#  'traffic',
#  'rumour',
#  'amiabl',
#  'mapl',
#  'scrupl',
#  'flow',
#  '_just_',
#  '_recollecting_',
#  'pud',
#  'heedless',
#  'orchard',
#  'hand',
#  '_each_',
#  'behav',
#  'coffe',
#  'impend',
#  'supper',
#  'rous',
#  'wittier',
#  'unseason',
#  'where',
#  'goodhumour',
#  'disinclin',
#  'invalid',
#  'examin',
#  'sell',
#  'dirti',
#  'domest',
#  'penetr',
#  'steadier',
#  'seduc',
#  'host',
#  'hazard',
#  'intermiss',
#  'endur',
#  'unfair',
#  'caress',
#  'mild',
#  'lip',
#  'commonplac',
#  'exclus',
#  'delus',
#  'instrument',
#  'dul',
#  'break',
#  '_married_',
#  'nonsens',
#  'checker-work',
#  'swept',
#  'feverish',
#  'crisi',
#  'side.',
#  'school-girl',
#  'it',
#  'they',
#  'unfeignedli',
#  "d'alman",
#  '_been_',
#  'whist',
#  'hear.',
#  'enchant',
#  'accent',
#  'limb',
#  'grievou',
#  'tire',
#  'Go',
#  'wrap',
#  'propriety.',
#  'difficulti',
#  'reason',
#  'dryness',
#  'argument',
#  '_party_',
#  'patronag',
#  'thou',
#  'upbraid',
#  'familiar',
#  'earliest',
#  'consequ',
#  'blind',
#  'relaps',
#  'press',
#  'impli',
#  'remain',
#  '_nearer_',
#  'move.',
#  'thi',
#  'vigor',
#  'captious.',
#  'security.',
#  'desultori',
#  'inn',
#  'defect',
#  'so.',
#  'whole',
#  'build',
#  'knee',
#  'front',
#  'mine',
#  'muffin',
#  'loudli',
#  'afflict',
#  'needless',
#  'slyness',
#  'midnight',
#  'attack',
#  '_of_',
#  'unmanag',
#  'heroin',
#  'fill',
#  'displeas',
#  'gentlemanlik',
#  'pitch',
#  'ceaseless',
#  'he',
#  'chat',
#  'april',
#  'steak',
#  'happy-look',
#  'march',
#  'them',
#  'represent',
#  'gaze',
#  'unpardon',
#  'pigeon-pi',
#  'content',
#  'insepar',
#  'footpath',
#  'conscience-stricken',
#  'consist',
#  'heroism',
#  'broader',
#  'concentr',
#  'Ah',
#  'vigour',
#  'insan',
#  'beauti',
#  'half-whisp',
#  'courtesi',
#  'steep',
#  'volum',
#  'support',
#  'lurk',
#  'cockad',
#  'moralis',
#  'muslin',
#  'impati',
#  'util',
#  "elton'",
#  'greet',
#  'relinquish',
#  'linguist',
#  'wade',
#  'card-tabl',
#  'exult',
#  'unworthi',
#  'congratul',
#  "woodhouse'",
#  'ill-humour',
#  "brother'",
#  'over-car',
#  'prospect',
#  'teacher',
#  'avail',
#  'madeira',
#  'disposit',
#  'angel',
#  'is',
#  'noth',
#  'peculiar',
#  'avert',
#  'chief',
#  'root',
#  'family-est',
#  'consult',
#  'dessert',
#  'tea-visit',
#  'concern.',
#  'bank',
#  'inhabit',
#  'open-hearted',
#  'close',
#  'crosser',
#  'indisput',
#  'spirit.',
#  'useless',
#  'beat',
#  'trim',
#  'besid',
#  'plot',
#  '_addition_',
#  'funer',
#  'proceed',
#  'door',
#  'strikingli',
#  'exhaust',
#  'manchester-street',
#  'georg',
#  'viii',
#  'windsor.',
#  'insult',
#  'heritag',
#  'secresi',
#  'rough',
#  '_we_',
#  'highest',
#  'lame',
#  'accustom',
#  'astley',
#  'meant',
#  'woeful',
#  'hope',
#  'mischiev',
#  'care.',
#  'queer',
#  'boil',
#  'candour',
#  'engraft',
#  'ought.',
#  'grievanc',
#  'serv',
#  'objection',
#  'forbear',
#  'behaviour.',
#  'enquir',
#  'deaden',
#  'if',
#  'sunk',
#  'indiscreetli',
#  'downright',
#  'encumbr',
#  'degrad',
#  'enhanc',
#  'obliging.',
#  'die',
#  'gentl',
#  'artific',
#  'with',
#  'trust',
#  'invention.',
#  'vehicl',
#  'directly.',
#  'sister-in-law',
#  'roundli',
#  'ask',
#  'slightest',
#  'slave-trad',
#  'doom',
#  'knowledg',
#  'charit',
#  'french',
#  'admit',
#  'depreci',
#  'known.',
#  'unwholesom',
#  'rang',
#  "harriet's.",
#  'scholar',
#  'forebod',
#  'apprehend',
#  'truth',
#  'workbag',
#  'harmless',
#  'credul',
#  'charg',
#  'dinner-tim',
#  'elsewher',
#  'respit',
#  'longest',
#  'collat',
#  'aliv',
#  'home-farm',
#  'conciliating.',
#  'screw',
#  'tuesday',
#  'hartfield',
#  'reluct',
#  'tempt',
#  'detest',
#  'thousands.',
#  'mine.',
#  'tediou',
#  'patriot',
#  'inquietud',
#  'misappli',
#  'dissolv',
#  'given',
#  'destin',
#  "daughter'",
#  'full',
#  'unnecessari',
#  'to',
#  'listless',
#  'sober',
#  'poultry-hous',
#  'lie',
#  'birmingham',
#  'oblig',
#  'outcri',
#  '_named_',
#  'puff',
#  "bates'",
#  'singl',
#  'accomplish',
#  'elm',
#  'exceedingli',
#  'polish',
#  'old',
#  'bought',
#  'dispar',
#  'preach',
#  'level',
#  'dissatisfact',
#  'had.',
#  'odiou',
#  'shift',
#  'next',
#  'oxford',
#  'unsuspected.',
#  'embarrassed.',
#  '_dixon_',
#  'strong',
#  'strawberry-b',
#  'occur',
#  'falsehood',
#  'indign',
#  'am.',
#  'requisite.',
#  'bent',
#  'sore',
#  'add',
#  'houseroom',
#  'continu',
#  'militia',
#  'wright',
#  'unlik',
#  'piqu',
#  'terror',
#  'pet',
#  'affection',
#  'situat',
#  'forgiv',
#  'coupl',
#  'distinct',
#  'wrapt',
#  'prodigi',
#  'post.',
#  'non-exist',
#  'tumbler',
#  'retent',
#  'shed',
#  'insuffer',
#  'sour',
#  'process',
#  'unexpens',
#  'implor',
#  'court-plaist',
#  'sinc',
#  'surrend',
#  'blank',
#  'manag',
#  'hitherto',
#  'account',
#  'preface.',
#  'scale',
#  'M.',
#  'despond',
#  'bandi',
#  'stray',
#  'dirt',
#  'proportion',
#  'born',
#  'enclos',
#  'govern',
#  'curiosity.',
#  'sight',
#  'nourish',
#  'knife',
#  'unmerit',
#  'park',
#  'instantli',
#  'I.',
#  'north',
#  'digniti',
#  'chatter',
#  'confess.',
#  'MY',
#  'lover.',
#  'dwindl',
#  'misbehav',
#  'walli',
#  'fling',
#  'mysteri',
#  'somewhere.',
#  'kind',
#  'male',
#  'confidant',
#  'tabl',
#  'twenti',
#  'distrust.',
#  'necess',
#  'toss',
#  'indulgence.',
#  'everyday',
#  '_appropriation_',
#  'stationari',
#  'flock',
#  'station',
#  'west',
#  'observe.',
#  'etc.',
#  'incred',
#  'devoid',
#  'minist',
#  'N.',
#  'clara',
#  'anticip',
#  'philipp',
#  'shade',
#  'eclat',
#  'john',
#  'thrown',
#  'encroach.',
#  'ribband',
#  'amidst',
#  'vacanc',
#  'conceal',
#  'background',
#  'grammat',
#  'outre',
#  'transact',
#  'sooth',
#  'felic',
#  'languor',
#  'their',
#  'insidi',
#  'fortuit',
#  'strictli',
#  'perpetu',
#  'request',
#  'downstair',
#  'instinct',
#  'impair.',
#  'sing',
#  'known',
#  'c.',
#  'placid',
#  'understood',
#  'sweet-cak',
#  'giggl',
#  'decorum',
#  'aye',
#  "weston'",
#  'ponder',
#  'uppermost',
#  "harriet'",
#  'injuri',
#  'profus',
#  'descri',
#  'alreadi',
#  'feed',
#  'hurri',
#  'bleak',
#  'wants.',
#  'labour',
#  'dull-look',
#  'amend',
#  'contemptu',
#  'persist',
#  'exultingli',
#  'sale',
#  'store',
#  'specimen',
#  'genli',
#  'argu',
#  'taylor',
#  'requisit',
#  'entreati',
#  'smith',
#  'at',
#  'retir',
#  'emot',
#  'report',
#  'permit',
#  'evas',
#  'over-trim',
#  'flake',
#  'ring',
#  'be',
#  'linen-drap',
#  'demand',
#  'size',
#  'humbl',
#  'mum',
#  'imagin',
#  'admir',
#  'advances.',
#  'inquir',
#  'charm',
#  'suitabl',
#  'warmer',
#  'shepherd',
#  'prove',
#  'english',
#  'top',
#  '_assistance_',
#  'casement',
#  "fairfax's.",
#  'protest',
#  'poplin',
#  'folli',
#  'sick-chamb',
#  'bake',
#  'method',
#  'addit',
#  'finest-look',
#  'happy.',
#  'invari',
#  'dire',
#  'vision',
#  'apologis',
#  '_promise_',
#  '_three_',
#  'nod',
#  'countri',
#  'F',
#  'open',
#  'certifi',
#  '_well_',
#  ']',
#  'charmingli',
#  '_bath_',
#  'blue',
#  'momentari',
#  '_secret_',
#  'lord',
#  'highli',
#  'declar',
#  'struck',
#  'rest.',
#  'mighti',
#  'credit',
#  'fish-pond',
#  'dork',
#  'irresist',
#  'infant',
#  'behalf',
#  'lighter',
#  'surround',
#  'equivoc',
#  'forest',
#  'absenc',
#  'flavour',
#  '_were_',
#  'dispers',
#  'broil',
#  '_then_',
#  'fold',
#  'ball',
#  'desperate.',
#  '_and_',
#  'tacitli',
#  'undesignedli',
#  '_housebreaking_',
#  'forgav',
#  'fineri',
#  'defici',
#  'nobil',
#  'quicksight',
#  'hundred.',
#  'country-d',
#  'hairdress',
#  'ungeni',
#  'romanc',
#  'money',
#  'judg',
#  'exercis',
#  'twofold',
#  'perceiv',
#  'wick',
#  'xviii',
#  'spoon',
#  'whiten',
#  'select',
#  'unluckili',
#  'suffered.',
#  'abdi',
#  'toward',
#  'swell',
#  'goldsmith',
#  'afford',
#  'impart',
#  'woodhouse.',
#  'taught',
#  'neither',
#  '_both_',
#  'ill-health',
#  'plainer',
#  'skil',
#  'kindl',
#  'ditch',
#  'preval',
#  'perform',
#  'incom',
#  'writing-desk',
#  'loth',
#  'gratitud',
#  'strive',
#  'piti',
#  'reverse.',
#  'doubli',
#  'however.',
#  'consumpt',
#  'arthur',
#  'tete-a-tet',
#  'lone',
#  'persuas',
#  'take',
#  'comparison',
#  'weymouth',
#  'fluentli',
#  'sheet',
#  'exceed',
#  'convenience.',
#  'hind-quart',
#  'resid',
#  'here',
#  'helpmat',
#  'doubl',
#  'inadmiss',
#  'meal',
#  'safe',
#  'figure-piec',
#  'roundabout',
#  'only.',
#  'pleasure.',
#  'song',
#  'huswif',
#  'pull',
#  'ador',
#  'third',
#  'escap',
#  'trident',
#  'mere',
#  'vari',
#  'ejacul',
#  'there.',
#  'design',
#  "father'",
#  'derang',
#  'refer',
#  'thwart',
#  'blush',
#  'trunk',
#  'imag',
#  'glori',
#  'bow',
#  'visitor',
#  'evening.',
#  'elton',
#  'sung',
#  'bread',
#  'coarser',
#  'pardon',
#  'circul',
#  'isabella',
#  'cope',
#  'refus',
#  'pursu',
#  'eatabl',
#  'intoler',
#  "yesterday'",
#  'insist',
#  'felt.',
#  'incongru',
#  'person',
#  'public',
#  'foresaw',
#  'exquisit',
#  'schoolroom',
#  'western',
#  'entertainingli',
#  'rid',
#  'hospit',
#  'VI',
#  'bed-tim',
#  'mitchel',
#  'moment',
#  'convivi',
#  'letter',
#  'beaver',
#  'kind-heart',
#  'spectacles.',
#  'leather',
#  'incumb',
#  'kind.',
#  'ill-tim',
#  'import',
#  'plan',
#  'goe',
#  'clayton',
#  'famili',
#  'needlessli',
#  'ascertain',
#  'rout-cak',
#  'brief',
#  'perus',
#  'appear',
#  'self-command',
#  'parentag',
#  'foresight',
#  'introduct',
#  'style',
#  'unconcern',
#  'jump',
#  'pantri',
#  'curv',
#  'flew',
#  'rest',
#  'crown',
#  'begin.',
#  'tan',
#  'La',
#  'oper',
#  'faint',
#  'alik',
#  'unsuccess',
#  'amiss',
#  'drive',
#  'custom',
#  'school',
#  'routin',
#  "ford's.",
#  ',',
#  'constant',
#  'gallantri',
#  'persuadable.',
#  'eight-and-thirti',
#  'involuntarili',
#  'impel',
#  'privat',
#  'implant',
#  'churchill.',
#  'ad',
#  'thoughts.',
#  'art',
#  'wet',
#  'disgustingli',
#  'aspect',
#  'wicked',
#  'irregular',
#  'unwelcom',
#  'imit',
#  'fear',
#  'interesting.',
#  '_court_',
#  'bang',
#  'hesit',
#  'Be',
#  'appel',
#  'morrow',
#  'part',
#  'anyth',
#  'delay',
#  'produc',
#  'happier',
#  'urgent',
#  'pause.',
#  'help',
#  'unqualifi',
#  'moderate-s',
#  'august',
#  'popularity.',
#  'short',
#  'seminari',
#  'curtain',
#  'fears.',
#  'closet',
#  'cowper',
#  'conclus',
#  'gift',
#  'retract',
#  'apolog',
#  'embrac',
#  'otways.',
#  'sufficient.',
#  'brother-in-law',
#  'protract',
#  'To',
#  'constancy.',
#  'vow',
#  'suckl',
#  'Is',
#  'recov',
#  'shine',
#  'expedi',
#  'amid',
#  'in',
#  'centr',
#  'consultation.',
#  'richli',
#  'princ',
#  'danc',
#  'hither',
#  'fellow',
#  '_marry_',
#  '_sposo_',
#  'rub',
#  'strangest',
#  'humourist',
#  'mercantil',
#  'tautolog',
#  'hate',
#  'sacrific',
#  'oath',
#  'fruit',
#  'inexpress',
#  'slice',
#  'civilli',
#  'heat',
#  'poor',
#  'attain',
#  'purs',
#  'deduct',
#  'driven',
#  'kindli',
#  'occasion',
#  'last',
#  'irrat',
#  ...}

# %% [markdown]
# ### Exercise 2.4
# *What is the most ambiguous stem in Austen's "Emma"? (meaning, which stem in Austen's "Emma" maps to the largest number of distinct tokens?)*

# %%
# Out:
# The most ambiguous stem is respect with words {'respectfully', 'respectably', 'respects', 'respected', 'respect', 'respectability', 'respectable', 'respective', 'respecting', 'respectful', 'Respect'}
